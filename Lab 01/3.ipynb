# %% [markdown]
# Chosen Industry: Healthcare
# Statistics
#
# Used to analyze patient data, disease trends, and treatment success rates.
#
# Example: calculating average recovery time or infection rates.
#
# Artificial Intelligence (AI)
#
# Rule-based expert systems for medical diagnosis.
#
# Example: systems that recommend treatments based on symptoms.
#
# Machine Learning (ML)
#
# Learns from historical patient data to predict diseases.
#
# Example: predicting diabetes or heart disease using patient records.
#
# Deep Learning (DL)
#
# Uses neural networks for complex tasks.
#
# Example: detecting tumors from MRI or X-ray images.
